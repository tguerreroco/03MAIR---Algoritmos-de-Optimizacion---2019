# %% [markdown]
# <a href="https://colab.research.google.com/github/tguerreroco/03MAIR---Algoritmos-de-Optimizacion---2019/blob/master/AG1/ordena_metodo_burbuja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def ordena_metodo_burbuja(lista):
    print("Algoritmo: ordena: ")
    print("Método: burbuja ")
    for numero in range(len(lista)-1,0,-1):
        print('1 Loop '+str(numero+1)+' elementos Lista:'+str(lista))
        for i in range(numero):
            if lista[i]>lista[i+1]:
               cambio_numero = lista[i]
               lista[i] = lista[i+1]
               lista[i+1] = cambio_numero
               print('Cambio elementos '+str(i)+' y '+str(i+1)+':'+str(lista[i]) +'   '+str(lista[i+1]))
    return lista

A = [9187, 244, 4054, 9222, 8373, 4993, 5265, 5470, 4519, 7182, 2035, 3506, 4337, 7580, 2554, 2824, 8357, 4447, 7379]
lista_ordenada=ordena_metodo_burbuja(A)
print("Lista ordenada: "+str(lista_ordenada))
# Out:
# Algoritmo: ordena:
# Método: burbuja
# 1 Loop 19 elementos Lista:[9187, 244, 4054, 9222, 8373, 4993, 5265, 5470, 4519, 7182, 2035, 3506, 4337, 7580, 2554, 2824, 8357, 4447, 7379]
# Cambio elementos 0 y 1:244   9187
# Cambio elementos 1 y 2:4054   9187
# Cambio elementos 3 y 4:8373   9222
# Cambio elementos 4 y 5:4993   9222
# Cambio elementos 5 y 6:5265   9222
# Cambio elementos 6 y 7:5470   9222
# Cambio elementos 7 y 8:4519   9222
# Cambio elementos 8 y 9:7182   9222
# Cambio elementos 9 y 10:2035   9222
# Cambio elementos 10 y 11:3506   9222
# Cambio elementos 11 y 12:4337   9222
# Cambio elementos 12 y 13:7580   9222
# Cambio elementos 13 y 14:2554   9222
# Cambio elementos 14 y 15:2824   9222
# Cambio elementos 15 y 16:8357   9222
# Cambio elementos 16 y 17:4447   9222
# Cambio elementos 17 y 18:7379   9222
# 1 Loop 18 elementos Lista:[244, 4054, 9187, 8373, 4993, 5265, 5470, 4519, 7182, 2035, 3506, 4337, 7580, 2554, 2824, 8357, 4447, 7379, 9222]
# ...
